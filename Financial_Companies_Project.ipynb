# %%
import pandas as pd
print(pd. __version__)
import sklearn
data=pd.read_excel("E:\Compinfodataset12345.xlsx")
data.head()
#Extracting independent and dependent variable
# Out:
# 1.0.5
#     RNDSpend  AdministrationSpend  MarketingSpend      Location     Profit  \
# 0  165349.20            136897.80       471784.10     Tech Park  192261.83
# 1  162597.70            151377.59       443898.53     Mindspace  191792.06
# 2  153441.51            101145.55       407934.54  Cyber Towers  191050.39
# 3  144372.41            118671.85       383199.62     Tech Park  182901.99
# 4  142107.34             91391.77       366168.42  Cyber Towers  166187.94
#
#    Annual Income  Profit pecentage  Application cost  Application tools cost  \
# 0      966292.93          0.248390      19808.380120             7870.159233
# 1      949665.88          0.253066       9405.602864            22910.406800
# 2      853571.99          0.288369       8050.676475            29313.909580
# 3      829145.87          0.283023      24208.981540             2684.648893
# 4      765855.47          0.277133       1384.624993            10013.167860
#
# ...

# %%
#import pandas
import pandas as pd
#load dataset
data= pd.read_excel("E:\Compinfodataset12345.xlsx")
data.head()
#Extracting Independent and dependent Variable  
x= data.iloc[:, [0,2]].values  #training data
y= data.iloc[:, 3].values    #testing data
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.60,random_state=0)
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)  
#Fitting RandomForestClasssifier to the training set  
from sklearn.ensemble import RandomForestClassifier  
classifier= RandomForestClassifier()   
classifier.fit(x_train, y_train)  
#Predicting the test set result  
y_pred= classifier.predict(x_test)  
from sklearn.metrics import accuracy_score  
print("Accuracy For RandomForestClassifier:",accuracy_score(y_test, y_pred))
print("\n\n============================================")
#Fitting DecisionTreeClassifier the training set  
from sklearn.tree import DecisionTreeClassifier  
classifier= DecisionTreeClassifier() 
classifier.fit(x_train, y_train)  
#Predicting the test set result  
y_pred= classifier.predict(x_test)  
from sklearn.metrics import accuracy_score  
print("Accuracy For DecisionTreeClassifier:",accuracy_score(y_test, y_pred))
print("\n\n============================================")
#Fitting LogisticRegression the training set  
from sklearn.linear_model import LogisticRegression  
classifier= LogisticRegression() 
classifier.fit(x_train, y_train)  
#Predicting the test set result  
y_pred= classifier.predict(x_test)  
from sklearn.metrics import accuracy_score  
print("Accuracy For LogisticRegression:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy For RandomForestClassifier: 0.24166666666666667
#
#
# ...
# Accuracy For DecisionTreeClassifier: 0.225
#
#
# ...
# Accuracy For LogisticRegression: 0.3
